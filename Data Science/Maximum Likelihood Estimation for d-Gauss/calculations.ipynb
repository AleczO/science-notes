# %% [markdown]
# $$ \text{Gaussian}(\mathbf{x}) = p(\mathbf{x} | \boldsymbol{\mu}, \mathbf{\Sigma}) =
# \frac{1}{\sqrt{(2\pi)^k |\mathbf{\Sigma}|}} \exp{ \bigg\{-\frac{1}{2}(\mathbf{x} - \boldsymbol{\mu})^T
# \mathbf{\Sigma}^{-1} (\mathbf{x} - \boldsymbol{\mu})
# \bigg\} }
# $$
#
# <br>
#
# $$ \{ \mathbf{x}_i \}_{i=1}^N $$

# %% [markdown]
# $$ \log \mathcal{L}(\boldsymbol{\mu}, \mathbf{\Sigma}) = \mathcal{l}(\boldsymbol{\mu}, \mathbf{\Sigma}) =
# \log \prod_{i=1}^{N} p(\mathbf{x}_i | \boldsymbol{\mu}, \mathbf{\Sigma}) $$
#
# $$ = N\log \frac{1}{\sqrt{(2\pi)^k |\mathbf{\Sigma}|}}
# - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \boldsymbol{\mu})^T \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu}) $$
#
# $$ = -\frac{N}{2} \log{(2\pi)^k |\mathbf{\Sigma}|}
# - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \boldsymbol{\mu})^T \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu}) $$
#
# $$ = -\frac{N}{2} \log{(2\pi)^k}
# -\frac{N}{2}\log{|\mathbf{\Sigma}|}
# - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \boldsymbol{\mu})^T \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu}) $$

# %% [markdown]
# $$ \frac{\partial \mathcal{l}}{\partial \boldsymbol{\mu}} = 0 $$
#
# $$ \sum_{i=1}^N
# \frac{\partial}{\partial \boldsymbol{\mu}}
# (\mathbf{x}_i - \boldsymbol{\mu})^T \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu}) = 0 $$
#
# <br>
#
# $$ \frac{d}{d\mathbf{x}} (\mathbf{x}^T \mathbf{B} \mathbf{x}) = 2\mathbf{B}\mathbf{x}
# \quad \text{for} \quad \mathbf{B} = \mathbf{B}^T
# $$
#
# <br>
#
# $$ 22 \sum_{i=1}^N \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu}) = 0  $$
#
# $$ \sum_{i=1}^N \mathbf{\Sigma}^{-1} \mathbf{x}_i
# - \sum_{i=1}^N \mathbf{\Sigma}^{-1} \boldsymbol{\mu} = 0  $$
#
# <br>
#
# $$ \mathbf{\Sigma}^{-1} \ \text{positive-definite} $$
#
# <br>
#
# $$\sum_{i=1}^N \mathbf{x}_i = \sum_{i=1}^N \boldsymbol{\mu}  $$
#
#
#
# $$ \sum_{i=1}^N \mathbf{x}_i = N\boldsymbol{\mu}  $$
#
# $$ \boldsymbol{\mu} = \frac{1}{N} \sum_{i=1}^N \mathbf{x}_i = \bar{\mathbf{x}}  $$

# %% [markdown]
# $$ \mathcal{l}(\boldsymbol{\mu}, \mathbf{\Sigma}) = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}|}  - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \boldsymbol{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu})  $$
#
# $$ |\mathbf{\Sigma}| = |\mathbf{\Sigma}^{-1}| $$
#
# $$ = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}^{-1}|}  - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \boldsymbol{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu})  $$
#
# <br>
#
# $$ (\mathbf{x}_i - \boldsymbol{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu}) \in \mathbb{R} $$
# $$ \land$$
# $$ c = \text{tr} (c) , \ \ \ c \in \mathbb{R} $$
#
# $$ (\mathbf{x}_i - \boldsymbol{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu}) = \text{tr}
# \big[  (\mathbf{x}_i - \boldsymbol{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu})   \big] $$
#
# <br>
#
# $$ = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}^{-1}|}  - \frac{1}{2} \sum_{i=1}^N \text{tr}
# \big[  (\mathbf{x}_i - \boldsymbol{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \boldsymbol{\mu})   \big]  $$
#
# <br>
#
# $$ \text{cyclic property} \ \ \ \ \ \text{tr}[\mathbf{A}\mathbf{B}\mathbf{C}] = \text{tr}[\mathbf{B}\mathbf{C}\mathbf{A}] = \text{tr}[\mathbf{C}\mathbf{A}\mathbf{B}] $$
#
# <br>
#
# $$ = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}^{-1}|}  - \frac{1}{2} \sum_{i=1}^N \text{tr}
# \big[ (\mathbf{x}_i - \boldsymbol{\mu})  (\mathbf{x}_i - \boldsymbol{\mu})^T  \mathbf{\Sigma}^{-1}   \big]  $$

# %% [markdown]
# $$ \frac{\partial\mathcal{l}}{\partial \mathbf{\Sigma}^{-1}} = 0 $$
#
# <br>
#
# $$ \frac{\partial}{\partial \mathbf{X}} = \text{tr}[\mathbf{A} \mathbf{X}] = \mathbf{A}^T $$
# $$ \frac{\partial}{\partial \mathbf{\Sigma}^{-1}} \text{tr} \big[ (\mathbf{x}_i - \boldsymbol{\mu})  (\mathbf{x}_i - \boldsymbol{\mu})^T  \mathbf{\Sigma}^{-1} \big] = [(\mathbf{x}_i - \boldsymbol{\mu})  (\mathbf{x}_i - \boldsymbol{\mu})^T]^T = (\mathbf{x}_i - \boldsymbol{\mu})  (\mathbf{x}_i - \boldsymbol{\mu})^T   $$
#
#
#
# <br>
#
#
#
#
# $$ \frac{N}{2}\mathbf{\Sigma} - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \boldsymbol{\mu})  (\mathbf{x}_i - \boldsymbol{\mu})^T  = 0 $$
#
#
# $$ \mathbf{\Sigma}
# =  \frac{1}{N} \sum_{i=1}^N (\mathbf{x}_i - \boldsymbol{\mu})  (\mathbf{x}_i - \boldsymbol{\mu})^T $$

# %% [markdown]
# - [The Matrix Cookbook](https://www.math.uwaterloo.ca/~hwolkowi/matrixcookbook.pdf)
