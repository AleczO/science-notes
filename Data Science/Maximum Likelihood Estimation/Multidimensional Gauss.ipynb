# %% [markdown]
# $$ \text{Gaussian}(\mathbf{x}) = p(\mathbf{x} | \mathbf{\mu}, \mathbf{\Sigma}) =
# \frac{1}{\sqrt{(2\pi)^k |\mathbf{\Sigma}|}} \exp{ \bigg\{-\frac{1}{2}(\mathbf{x} - \mathbf{\mu})^T
# \mathbf{\Sigma}^{-1} (\mathbf{x} - \mathbf{\mu})
# \bigg\} }
# $$
#
# <br>
#
# $$ \{ \mathbf{x}_i \}_{i=1}^N $$

# %% [markdown]
# $$ \log \mathcal{L}(\mathbf{\mu}, \mathbf{\Sigma}) = \mathcal{l}(\mathbf{\mu}, \mathbf{\Sigma}) =
# \log \prod_{i=1}^{N} p(\mathbf{x}_i | \mathbf{\mu}, \mathbf{\Sigma}) $$
#
#
# $$ = N\log \frac{1}{\sqrt{(2\pi)^k |\mathbf{\Sigma}|}} - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu})  $$
#
# $$ = -\frac{N}{2} \log{(2\pi)^k |\mathbf{\Sigma}|}  - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu})  $$
#
# $$ = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}|}  - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu})  $$

# %% [markdown]
# $$ \frac{\partial \mathcal{l}}{\partial \mathcal{\mu}} = 0 $$
#
#
# $$ \sum_{i=1}^N \frac{\partial}{\partial \mu} (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu}) = 0 $$
#
# <br>
#
# $$ \mathbf{x}^T \mathbf{B} \mathbf{x} = 2\mathbf{B} \mathbf{x} $$
#
# <br>
#
# $$ 2 \sum_{i=1}^N \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu}) = 0 $$
#
# $$ \sum_{i=1}^N \mathbf{\Sigma}^{-1} \mathbf{x}_i - \sum_{i=1}^N \mathbf{\Sigma}^{-1} \mathbf{\mu} = 0 $$
#
# <br>
#
# $$ \Sigma^{-1} \ \text{positive-definite} $$
#
# <br>
#
# $$ \sum_{i=1}^N \mathbf{x}_i =  \sum_{i=1}^N \mathbf{\mu} $$
#
#
#
# $$ \sum_{i=1}^N \mathbf{x}_i =  N\mathbf{\mu} $$
#
# $$ \mathbf{\mu}  =  \frac{1}{N} \sum_{i=1}^N \mathbf{x}_i = \bar{\mathbf{x}} $$

# %% [markdown]
# $$ \mathcal{l}(\mathbf{\mu}, \mathbf{\Sigma}) = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}|}  - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu})  $$
#
# $$ |\mathbf{\Sigma}| = |\mathbf{\Sigma}^{-1}| $$
#
# $$ = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}^{-1}|}  - \frac{1}{2} \sum_{i=1}^N (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu})  $$
#
# <br>
#
# $$ (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu}) \in \mathbb{R} $$
# $$ \land$$
# $$ c = \text{tr} (c) , \ \ \ c \in \mathbb{R} $$
#
# $$ (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu}) = \text{tr}
# \big[  (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu})   \big] $$
#
# <br>
#
# $$ = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}^{-1}|}  - \frac{1}{2} \sum_{i=1}^N \text{tr}
# \big[  (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1} (\mathbf{x}_i - \mathbf{\mu})   \big]  $$
#
# <br>
#
# $$ \text{cyclic property} \ \ \ \ \ \text{tr}[ABC] = \text{tr}[BCA] = \text{tr}[CAB] $$
#
# <br>
#
# $$ = -\frac{N}{2} \log{(2\pi)^k} -\frac{N}{2}\log{|\mathbf{\Sigma}^{-1}|}  - \frac{1}{2} \sum_{i=1}^N \text{tr}
# \big[ (\mathbf{x}_i - \mathbf{\mu})  (\mathbf{x}_i - \mathbf{\mu})^T  \mathbf{\Sigma}^{-1}   \big]  $$

# %% [markdown]
# $$ \frac{\partial\mathcal{l}}{\partial \mathbf{\Sigma}^{-1}} = 0 $$
#
#
# $$ \frac{N}{2}\mathbf{\Sigma} - \frac{1}{2} \sum_{i=1}^N \text(\mathbf{x}_i - \mathbf{\mu})  (\mathbf{x}_i - \mathbf{\mu})^T  = 0 $$
#
# $$ \mathbf{\Sigma}
# =  \frac{1}{N} \sum_{i=1}^N (\mathbf{x}_i - \mathbf{\mu})  (\mathbf{x}_i - \mathbf{\mu})^T $$
